# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import plotly.colors as colors
import warnings
warnings.filterwarnings('ignore')

pio.templates.default = 'plotly_white'

# %%
data = pd.read_excel('Sample - Superstore.xls')

# %%
data.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2019-103800 2019-01-03 2019-01-07  Standard Class    DP-13000
# 1       2  US-2019-112326 2019-01-04 2019-01-08  Standard Class    PO-19195
# 2       3  US-2019-112326 2019-01-04 2019-01-08  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States     Houston  ...       77095
# 1  Phillina Ober  Home Office  United States  Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States  Naperville  ...       60540
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
# 2  Central  OFF-LA-10003223  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
data.describe()
# Out:
#              Row ID         Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5097.500000    228.225854      3.791838      0.155385     28.673417
# std     2942.898656    619.906839      2.228317      0.206249    232.465115
# min        1.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%     2549.250000     17.220000      2.000000      0.000000      1.760800
# 50%     5097.500000     53.910000      3.000000      0.200000      8.690000
# 75%     7645.750000    209.500000      5.000000      0.200000     29.297925
# max    10194.000000  22638.480000     14.000000      0.800000   8399.976000

# %%
data.nunique()
# Out:
# Row ID            10194
# Order ID           5111
# Order Date         1242
# Ship Date          1338
# Ship Mode             4
# Customer ID         804
# Customer Name       800
# Segment               3
# Country/Region        2
# City                542
# State/Province       59
# Postal Code         654
# Region                4
# Product ID         1862
# Category              3
# Sub-Category         17
# Product Name       1849
# Sales              6161
# Quantity             14
# Discount             12
# Profit             7597
# dtype: int64

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])                     ## converting the Strings type data type to the significant value by single values:-
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
data['Order Month'] = data['Order Date'].dt.month
data['Order Year'] = data['Order Date'].dt.year
data['OrderDat of Week'] = data['Order Date'].dt.dayofweek

# %%
data.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2019-103800 2019-01-03 2019-01-07  Standard Class    DP-13000
# 1       2  US-2019-112326 2019-01-04 2019-01-08  Standard Class    PO-19195
# 2       3  US-2019-112326 2019-01-04 2019-01-08  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City  ...  \
# 0  Darren Powers     Consumer  United States     Houston  ...
# 1  Phillina Ober  Home Office  United States  Naperville  ...
# 2  Phillina Ober  Home Office  United States  Naperville  ...
#
#           Category Sub-Category  \
# 0  Office Supplies        Paper
# 1  Office Supplies      Binders
# 2  Office Supplies       Labels
#
#                                         Product Name   Sales Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.448        2
# 1         GBC Standard Plastic Binding Systems Combs   3.540        2
# ...

# %%
data.tail(2)
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 10192   10193  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10193   10194  CA-2022-143500 2022-12-30 2023-01-03  Standard Class
#
#       Customer ID      Customer Name   Segment Country/Region           City  \
# 10192    PO-18865  Patrick O'Donnell  Consumer  United States  New York City
# 10193    HO-15230        Harry Olson  Consumer         Canada  Charlottetown
#
#        ...         Category Sub-Category                 Product Name   Sales  \
# 10192  ...       Technology       Phones    Gear Head AU3700S Headset  90.930
# 10193  ...  Office Supplies      Binders  Wilson Jones Impact Binders   3.024
#
#       Quantity Discount  Profit  Order Month  Order Year  OrderDat of Week
# 10192        7      0.0  2.7279           12        2022                 4
# 10193        3      0.2 -0.6048           12        2022                 4
#
# [2 rows x 24 columns]

# %%
## Q. Find the monthly sales of the company ? :-

# %%
sales_by_month = data.groupby('Order Month')['Sales'].sum().reset_index()
fig = px.line(sales_by_month,x = 'Order Month', y =  'Sales', title = "Monthly basis Sales for company")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## from the we concluded that jan having very low sales as we have surpassing sales in december.so linearly we are having in profit way.

# %%
## Q-- Total Analysis of sales by Category( Tech. Office supplies, Furnitures) ?-

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Order Month', 'Order Year', 'OrderDat of Week'],
#       dtype='object')

# %%
sales_by_category = data.groupby('Category')['Sales'].sum().reset_index()
fig = px.bar(sales_by_category,x = 'Category', y = 'Sales', title = "Monthly basis Category sales  for company")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## we can also carry out the the pie chart but in the different fashions:-

sales_by_category = data.groupby('Category')['Sales'].sum().reset_index()
fig = px.pie(sales_by_category,
             names = 'Category',
             values = 'Sales',
             hole = 0.5,
             color_discrete_sequence=px.colors.qualitative.Pastel1)

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(title_text = 'Sales analysis by category',title_font = dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Order Month', 'Order Year', 'OrderDat of Week'],
#       dtype='object')

# %%
## Q -- Total Analysis of monthly Profits :-

profit_by_Months = data.groupby('Order Month')['Profit'].sum().reset_index()
fig = px.bar(profit_by_Months,x = 'Order Month', y = 'Profit', title = "Monthly basis Profits  for company")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
profit_by_Months    ##From the above we found that in Dec we are having highest profits above all months as compared to september.
# Out:
#     Order Month      Profit
# 0             1   9497.2501
# 1             2  10294.6107
# 2             3  29345.0405
# 3             4  11625.5223
# 4             5  22850.0324
# 5             6  21508.2067
# 6             7  14013.5496
# 7             8  22942.4239
# 8             9  37234.5608
# 9            10  33214.5143
# 10           11  35541.2553
# 11           12  44229.8480

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Order Month', 'Order Year', 'OrderDat of Week'],
#       dtype='object')

# %%
## Q--- Total Analysis of  Profits through categories :-
profit_by_Category = data.groupby('Category')['Profit'].sum().reset_index()
fig = px.bar(profit_by_Category,x = 'Category', y = 'Profit', title = "Total Analysis of profits through categories")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
profit_by_Category             ## From the above we showed, that technologies is higher than Office Supplies than the least Furnitures.
# Out:
#           Category       Profit
# 0        Furniture   19729.9956
# 1  Office Supplies  126023.4434
# 2       Technology  146543.3756

# %%
profit_by_category = data.groupby('Category')['Profit'].sum().reset_index()
fig = px.pie(profit_by_category,
             names = 'Category',
             values = 'Profit',
             hole = 0.5,
             color_discrete_sequence=px.colors.qualitative.Pastel_r)


fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(title_text = 'Profit analysis by category',title_font = dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Order Month', 'Order Year', 'OrderDat of Week'],
#       dtype='object')

# %%
## Q--- Total Analysis of  Sales & Profits combinely  through Customer Segments  for Company settlements:-
profit_Sales_by_Category = data.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()
profit_Sales_by_Category
# Out:
#        Segment         Sales       Profit
# 0     Consumer  1.170660e+06  136371.4463
# 1    Corporate  7.158061e+05   94249.6400
# 2  Home Office  4.400684e+05   61675.7283

# %%
profit_Sales_by_Segment= data.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()
color_palette = colors.qualitative.Pastel1

fig = go.Figure()
fig.add_trace(go.Bar(x = profit_Sales_by_Segment['Segment'],
                     y = profit_Sales_by_Segment['Sales'],
                     name = 'Sales',
                     marker_color = color_palette[6]))

fig.add_trace(go.Bar(x = profit_Sales_by_Segment['Segment'],
                     y = profit_Sales_by_Segment['Profit'],
                     name = 'Profit',
                     marker_color = color_palette[0]))
fig.update_layout(title = 'Sales and Profits Of Company Through Segment sections', xaxis_title = 'Customer_Segment', yaxis_title = 'Amount')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## From above Analysis of Stacked Bar Chart , we escalated that consumers are the most users as compared tp the Corporate and Home Office Personel, showing values
# double than the second and third items.
# So, the company should take the vital step to promote their products more to the normal consumers for better upcoming drastic profits and sales.
## Marketing team should give more time in campaign to promote appliances in faster way towards the users.
